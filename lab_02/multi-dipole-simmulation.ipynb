# %% [markdown]
# <div align="center">
#
# ### Lab 02 | The Physics of EEG
#
# ### Cortical Dipoles • Neuronal Synchrony • Signal Formation
#
# ---
#
# **Programming Environment:** Python
# **Libraries:** NumPy • Matplotlib
# **Methodology:** Computational Simulation
#
# </div>
#
# ---
#
# #### Learning Outcomes
#
# By completing this lab, you will be able to:
#
# ---
# ###
# 1.	Simulate neuronal synchrony and quantify how it affects EEG amplitude
# 2.	Model a simplified dipole potential and quantify the effect of depth (distance)
# 3.	Model dipole orientation effects and programmatically detect key angles
# 4.	Simulate multi-dipole interference and relate it to EEG spatial resolution
# 5.	Produce plots + numeric metrics as evidence

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

def rms(x):
    return np.sqrt(np.mean(x**2))

def peak_abs(x):
    return np.max(np.abs(x))

# %% [markdown]
# ### Part A — Neuronal Synchrony: Simulation + Quantification

# %% [markdown]
# #### Step 1 – Generate synchronous vs asynchronous population signals (Run as-is)

# %%
t = np.linspace(0, 1, 1000)   # 1 second
f = 10                        # 10 Hz rhythm
N = 50                        # number of neurons

# Synchronous neurons: same phase
sync_signal = np.sum([np.sin(2*np.pi*f*t) for _ in range(N)], axis=0)

# Asynchronous neurons: random phase
async_signal = np.sum([np.sin(2*np.pi*f*t + np.random.rand()*2*np.pi) for _ in range(N)], axis=0)

plt.figure(figsize=(10,4))
plt.plot(t, sync_signal, label="Sync")
plt.plot(t, async_signal, label="Async", alpha=0.7)
plt.title("Population Signal: Synchronous vs Asynchronous (N=50, f=10Hz)")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (a.u.)")
plt.legend()
plt.show()

# %% [markdown]
# #### Step 2 – Compute amplitude metrics

# %%
# TODO 1: Compute RMS and Peak amplitude for sync_signal
sync_rms = None
sync_peak = None

# TODO 2: Compute RMS and Peak amplitude for async_signal
async_rms = None
async_peak = None

print("Sync RMS:", sync_rms, "Sync Peak:", sync_peak)
print("Async RMS:", async_rms, "Async Peak:", async_peak)
# Out:
# Sync RMS: None Sync Peak: None
# Async RMS: None Async Peak: None

# %% [markdown]
# #### Step 3 – Experiment: RMS vs Neuron Count

# %% [markdown]
# Student Task: Create a loop for different N values and plot RMS scaling.
#
# Output expectation:
# Sync RMS should increase much faster than Async RMS
# Shows EEG measures synchrony

# %%
Ns = [5, 10, 20, 50, 100, 200]
sync_rms_list = []
async_rms_list = []

for N in Ns:
    sync = np.sum([np.sin(2*np.pi*f*t) for _ in range(N)], axis=0)
    async_ = np.sum([np.sin(2*np.pi*f*t + np.random.rand()*2*np.pi) for _ in range(N)], axis=0)

    # TODO 3: append RMS values to sync_rms_list and async_rms_list
    #sync_rms_list.append(...)
    #async_rms_list.append(...)
    

plt.figure()
plt.plot(Ns, sync_rms_list, marker='o', label="Sync RMS")
plt.plot(Ns, async_rms_list, marker='o', label="Async RMS")
plt.title("RMS vs Number of Neurons (Synchrony Effect)")
plt.xlabel("Number of neurons (N)")
plt.ylabel("RMS amplitude")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 15
#       9     # TODO 3: append RMS values to sync_rms_list and async_rms_list
#      10     #sync_rms_list.append(...)
#      11     #async_rms_list.append(...)
#      14 plt.figure()
# ---> 15 plt.plot(Ns, sync_rms_list, marker='o', label="Sync RMS")
#      16 plt.plot(Ns, async_rms_list, marker='o', label="Async RMS")
#      17 plt.title("RMS vs Number of Neurons (Synchrony Effect)")
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)
#    3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:494, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     491     axes.yaxis.update_units(y)
#     493 if x.shape[0] != y.shape[0]:
# --> 494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#     496 if x.ndim > 2 or y.ndim > 2:
#     497     raise ValueError(f"x and y can be no greater than 2D, but have "
#     498                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (6,) and (0,)

# %% [markdown]
# ### Part B — Dipole Depth Effect: Voltage vs Distance

# %% [markdown]
# #### Step 4 – Simulate dipole potential vs distance (Run as-is)
# We use a simplified relationship:
# ![alt text](image.png)
#
# Where:
#
# V = electric potential
# p = dipole strength
# r = distance from dipole
# This is a simplified forward model.

# %%
r = np.linspace(0.01, 0.25, 200)  # distance
p = 1.0                           # dipole strength

V = p / (r**2)

plt.figure()
plt.plot(r, V)
plt.title("Dipole Potential vs Distance (V ∝ 1/r²)")
plt.xlabel("Distance (r)")
plt.ylabel("Potential (a.u.)")
plt.show()

# %% [markdown]
# #### Step 5 – Depth experiment: compare multiple depths (Complete TODO)

# %% [markdown]
# Student Task: For each depth, compute peak potential and plot.
#
# Output expectation:Peak potential drops rapidly as depth increases

# %%
depths = [0.02, 0.05, 0.10, 0.20]  # deeper = larger r
peaks = []

for d in depths:
    # TODO 4: compute potential at distance d and append to peaks
    # peaks.append(...)
    pass

plt.figure()
plt.plot(depths, peaks, marker='o')
plt.title("Peak Potential vs Depth")
plt.xlabel("Depth (distance from scalp)")
plt.ylabel("Peak Potential (a.u.)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 10
#       7     pass
#       9 plt.figure()
# ---> 10 plt.plot(depths, peaks, marker='o')
#      11 plt.title("Peak Potential vs Depth")
#      12 plt.xlabel("Depth (distance from scalp)")
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)
#    3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:494, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     491     axes.yaxis.update_units(y)
#     493 if x.shape[0] != y.shape[0]:
# --> 494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#     496 if x.ndim > 2 or y.ndim > 2:
#     497     raise ValueError(f"x and y can be no greater than 2D, but have "
#     498                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (4,) and (0,)

# %% [markdown]
# ### Part C — Dipole Orientation Effect (Visibility in EEG)

# %% [markdown]
# We now extend the dipole equation:![Capture.PNG](attachment:Capture.PNG)
#
# 	p= dipole strength
# 	r= distance
# 	θ= orientation angle between dipole axis and electrode

# %% [markdown]
# #### Step 6 – Plot voltage vs orientation (Run as-is)

# %%
theta = np.linspace(0, np.pi, 200)
r_fixed = 0.1
p = 1.0

V_theta = (p * np.cos(theta)) / (r_fixed**2)

plt.figure()
plt.plot(theta, V_theta)
plt.axhline(0, linestyle='--')
plt.title("Dipole Potential vs Orientation (cos θ effect)")
plt.xlabel("θ (radians)")
plt.ylabel("Potential (a.u.)")
plt.show()

# %% [markdown]
# #### Step 7 – Detect key angles programmatically (Complete TODO)

# %% [markdown]
# Student Task: Find angle where potential is ~0 and where it is maximum.
# Expected:
#
#     Zero near π/2
#     Max near 0

# %%
# TODO 5: angle where V_theta is closest to 0
theta_zero = None

# TODO 6: angle where V_theta is maximum
theta_max = None

print("Zero-potential angle (approx):", theta_zero)
print("Max-potential angle:", theta_max)
# Out:
# Zero-potential angle (approx): None
# Max-potential angle: None

# %% [markdown]
# ### Part D — Two Dipoles Interference (Spatial Resolution)

# %% [markdown]
# #### Step 8 – Create 2D grid and simulate fields (Run as-is)

# %%
x = np.linspace(-1, 1, 200)
y = np.linspace(-1, 1, 200)
X, Y = np.meshgrid(x, y)

eps = 0.02  # avoid division by zero

# %% [markdown]
# #### tep 9 – Two dipoles at different positions (Complete TODO)

# %% [markdown]
# Student Task: Implement dipole1, dipole2 and combine.

# %%
# Dipole positions
x1, y1 = -0.3, 0
x2, y2 =  0.3, 0

# TODO 7: compute distance R1 and R2
# R1 = ...
# R2 = ...

# TODO 8: compute potentials V1 and V2 using 1/(R^2 + eps)
# V1 = ...
# V2 = ...

V_total = None  # TODO 9: V_total = V1 + V2

plt.figure(figsize=(6,5))
plt.contourf(X, Y, V_total, levels=60)
plt.colorbar(label="Potential")
plt.title("Two Dipoles: Combined Field")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 16
#      13 V_total = None  # TODO 9: V_total = V1 + V2
#      15 plt.figure(figsize=(6,5))
# ---> 16 plt.contourf(X, Y, V_total, levels=60)
#      17 plt.colorbar(label="Potential")
#      18 plt.title("Two Dipoles: Combined Field")
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:3190, in contourf(data, *args, **kwargs)
#    3188 @_copy_docstring_and_deprecators(Axes.contourf)
#    3189 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 3190     __ret = gca().contourf(
#    3191         *args, **({"data": data} if data is not None else {}), **kwargs
#    3192     )
#    3193     if __ret._A is not None:  # type: ignore[attr-defined]
#    3194         sci(__ret)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:6797, in Axes.contourf(self, *args, **kwargs)
#    6786 """
#    6787 Plot filled contours.
#    6788
#    (...)
#    6794 %(contour_doc)s
#    6795 """
#    6796 kwargs['filled'] = True
# -> 6797 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6798 self._request_autoscale_view()
#    6799 return contours
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\contour.py:701, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     697 if self.negative_linestyles is None:
#     698     self.negative_linestyles = \
#     699         mpl.rcParams['contour.negative_linestyle']
# --> 701 kwargs = self._process_args(*args, **kwargs)
#     702 self._process_levels()
#     704 self._extend_min = self.extend in ['min', 'both']
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\contour.py:1319, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1316         corner_mask = mpl.rcParams['contour.corner_mask']
#    1317 self._corner_mask = corner_mask
# -> 1319 x, y, z = self._contour_args(args, kwargs)
#    1321 contour_generator = contourpy.contour_generator(
#    1322     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1323     line_type=contourpy.LineType.SeparateCode,
#    1324     fill_type=contourpy.FillType.OuterCode,
#    1325     chunk_size=self.nchunk)
#    1327 t = self.get_transform()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\contour.py:1359, in QuadContourSet._contour_args(self, args, kwargs)
#    1357 elif 2 < nargs <= 4:
#    1358     x, y, z_orig, *args = args
# -> 1359     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1361 else:
#    1362     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\contour.py:1385, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1382 z = ma.asarray(z)
#    1384 if z.ndim != 2:
# -> 1385     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1386 if z.shape[0] < 2 or z.shape[1] < 2:
#    1387     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1388                     f"but has shape {z.shape}")
#
# TypeError: Input z must be 2D, not 0D

# %% [markdown]
# #### Step 10 – Move dipoles closer and observe merging (Complete TODO)

# %% [markdown]
# Student Task: Implement dipole1, dipole2 and combine.

# %%
# Dipole positions
x1, y1 = -0.3, 0
x2, y2 =  0.3, 0

# TODO 7: compute distance R1 and R2
# R1 = ...
# R2 = ...

# TODO 8: compute potentials V1 and V2 using 1/(R^2 + eps)
# V1 = ...
# V2 = ...

V_total = None  # TODO 9: V_total = V1 + V2

plt.figure(figsize=(6,5))
plt.contourf(X, Y, V_total, levels=60)
plt.colorbar(label="Potential")
plt.title("Two Dipoles: Combined Field")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 16
#      13 V_total = None  # TODO 9: V_total = V1 + V2
#      15 plt.figure(figsize=(6,5))
# ---> 16 plt.contourf(X, Y, V_total, levels=60)
#      17 plt.colorbar(label="Potential")
#      18 plt.title("Two Dipoles: Combined Field")
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:3190, in contourf(data, *args, **kwargs)
#    3188 @_copy_docstring_and_deprecators(Axes.contourf)
#    3189 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 3190     __ret = gca().contourf(
#    3191         *args, **({"data": data} if data is not None else {}), **kwargs
#    3192     )
#    3193     if __ret._A is not None:  # type: ignore[attr-defined]
#    3194         sci(__ret)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:6797, in Axes.contourf(self, *args, **kwargs)
#    6786 """
#    6787 Plot filled contours.
#    6788
#    (...)
#    6794 %(contour_doc)s
#    6795 """
#    6796 kwargs['filled'] = True
# -> 6797 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6798 self._request_autoscale_view()
#    6799 return contours
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\contour.py:701, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     697 if self.negative_linestyles is None:
#     698     self.negative_linestyles = \
#     699         mpl.rcParams['contour.negative_linestyle']
# --> 701 kwargs = self._process_args(*args, **kwargs)
#     702 self._process_levels()
#     704 self._extend_min = self.extend in ['min', 'both']
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\contour.py:1319, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1316         corner_mask = mpl.rcParams['contour.corner_mask']
#    1317 self._corner_mask = corner_mask
# -> 1319 x, y, z = self._contour_args(args, kwargs)
#    1321 contour_generator = contourpy.contour_generator(
#    1322     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1323     line_type=contourpy.LineType.SeparateCode,
#    1324     fill_type=contourpy.FillType.OuterCode,
#    1325     chunk_size=self.nchunk)
#    1327 t = self.get_transform()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\contour.py:1359, in QuadContourSet._contour_args(self, args, kwargs)
#    1357 elif 2 < nargs <= 4:
#    1358     x, y, z_orig, *args = args
# -> 1359     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1361 else:
#    1362     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\contour.py:1385, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1382 z = ma.asarray(z)
#    1384 if z.ndim != 2:
# -> 1385     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1386 if z.shape[0] < 2 or z.shape[1] < 2:
#    1387     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1388                     f"but has shape {z.shape}")
#
# TypeError: Input z must be 2D, not 0D

# %% [markdown]
# #### Step 10 – Move dipoles closer and observe merging (Complete TODO)

# %% [markdown]
# Student Task: Repeat the simulation for closer dipoles.
#
# Change:
#
# x1, x2 = -0.1, 0.1
#
# Compare:
#
#     Field overlap increases
#
#     Harder to distinguish two sources
#
#     Demonstrates poor spatial resolution

# %% [markdown]
# ##### Short Computational Conclusions
#
# Write 1–2 lines for each:
#
# How does RMS scale with N for sync vs async?
#
# What happens to potential when depth increases?
#
# Which orientation gives near-zero EEG voltage?
#
# What happens when two dipoles get closer?
